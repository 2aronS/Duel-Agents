# %% [raw]
# ---
# sidebar_label: Duel Agents
# ---

# %% [markdown]
# # ChatDuel
#
# This notebook provides a quick overview for getting started with Duel Agents [chat models](/docs/concepts/chat_models). Duel Agents routes each prompt against multiple models and bills the cheapest answer that still wins, behind an OpenAI-compatible proxy.
#
# ## Overview
#
# ### Integration details
#
# | Class | Package | Local | Serializable | Package downloads | Package latest |
# | :--- | :--- | :---: | :---: | :---: | :---: |
# | [ChatDuel](https://github.com/2aronS/Duel-Agents/tree/main/python/langchain-duel) | [langchain-duel](https://pypi.org/project/langchain-duel/) | ❌ | ❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/langchain-duel?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/langchain-duel?style=flat-square&label=%20) |
#
# ## Setup
#
# Create an API key at [duelagents.com/dashboard/settings](https://duelagents.com/dashboard/settings) (an active subscription is required).

# %% [markdown]
# ### Credentials
#
# Set your Duel API key as an environment variable.

# %%
import getpass
import os

if not os.getenv("DUEL_API_KEY"):
    os.environ["DUEL_API_KEY"] = getpass.getpass("Enter your Duel API key: ")

# %% [markdown]
# ### Installation
#
# The LangChain Duel Agents integration lives in the `langchain-duel` package:

# %%
# %pip install -qU langchain-duel

# %% [markdown]
# ## Instantiation

# %%
from langchain_duel import ChatDuel

llm = ChatDuel(
    model="duel-auto",
    temperature=0,
)

# %% [markdown]
# ## Invocation

# %%
messages = [
    ("system", "You are a helpful assistant that answers concisely."),
    ("human", "Explain concurrent agents in one sentence."),
]
ai_msg = llm.invoke(messages)
ai_msg.content

# %% [markdown]
# ## Chaining
#
# We can [chain](/docs/how_to/sequence/) the model with a prompt template like so:

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate(
    [
        ("system", "You translate {input_language} to {output_language}."),
        ("human", "{input}"),
    ]
)

chain = prompt | llm
chain.invoke(
    {
        "input_language": "English",
        "output_language": "French",
        "input": "I love programming.",
    }
)

# %% [markdown]
# ## API reference
#
# `ChatDuel` subclasses `langchain_openai.ChatOpenAI`, so it supports the same parameters and methods. See the [ChatOpenAI API reference](https://python.langchain.com/api_reference/openai/chat_models/langchain_openai.chat_models.base.ChatOpenAI.html) for details.
